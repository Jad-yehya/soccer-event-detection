# %% [markdown]
# # CNN to detect Football event from non football event

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 28.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0)
# Collecting huggingface-hub (from timm)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 28.9 MB/s eta 0:00:00
# Collecting safetensors (from timm)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: safetensors, huggingface-hub, timm
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 timm-0.9.2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils
import torch.distributions
from torchvision import transforms, models, datasets
import numpy as np
import matplotlib.pyplot as plt; plt.rcParams['figure.dpi'] = 200
from PIL import Image
Image.LOAD_TRUNCATED_IMAGES = True
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from tqdm.notebook import tqdm
import os
import zipfile
import timm

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE
# Out:
# device(type='cuda')

# %%
model = timm.create_model('dm_nfnet_f0.dm_in1k', pretrained=True).to(DEVICE)

# %%
# torch.save(model.state_dict(), 'dm_nfnet.pth')

# %%
model.get_classifier()
# Out:
# Linear(in_features=3072, out_features=1000, bias=True)

# %%
model.get_classifier().out_features = 2

# %%
model.get_classifier()
# Out:
# Linear(in_features=3072, out_features=2, bias=True)

# %%
# Freezing all the layers except the Classifier for the transfer learning
for param in model.parameters():
    param.requires_grad = False

for param in model.get_classifier().parameters():
    param.requires_grad = True

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# %%
def save_checkpoint(model, optimizer, train_loss, test_loss, train_acc, valid_acc, epoch, batch_idx, checkpoint_path):
    state = {'model': model.state_dict(),
             'optimizer': optimizer.state_dict(),
             'train_loss': train_loss,
             'test_loss': test_loss,
             'train_acc': train_acc,
             'valid_acc': valid_acc,
             'epoch': epoch,
             'batch_idx': batch_idx}
    torch.save(state, checkpoint_path)
    print('Model saved to %s.' % checkpoint_path)

# %%
def train(model, criterion, optimizer, train_loader, val_loader, save_location, checkpoint_location, early_stop=3, n_epochs=10, print_every=1):
    # Initializing variables
    valid_acc_max = 0
    stop_count = 0
    model.epochs = 0

    train_acc_list = []
    val_acc_list = []

    train_loss_list = []
    val_loss_list = []

    model.to(DEVICE)

    # Loop starts here
    for epoch in tqdm(range(n_epochs)):
        train_loss = 0
        valid_loss = 0

        train_acc = 0
        valid_acc = 0

        model.train()

        # Batch control
        batch_num = 0

        for data, label in train_loader:
            batch_num += 1
            data = data.to(DEVICE)  # Move data to the same device as the model
            label = label.to(DEVICE)  # Move label to the same device as the model

            output = model(data)

            loss = criterion(output, label)
            optimizer.zero_grad()

            loss.backward()
            optimizer.step()

            # Track train loss by multiplying average loss by number of examples in batch
            train_loss += loss.item() * data.size(0)

            # Calculate accuracy by finding max log probability
            _, pred = torch.max(output, dim=1)

            correct_tensor = pred.eq(label.data.view_as(pred))
            accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))
            train_acc += accuracy.item() * data.size(0)

            if batch_num % 10 == 0:
                print(f'Epoch: {epoch}\t{100 * (batch_num + 1) / len(train_loader):.2f}% complete.')

        model.epochs += 1

        if val_loader is not None:
            with torch.no_grad():
                model.eval()
                for data, label in val_loader:
                    data = data.to(DEVICE)  # Move data to the same device as the model
                    label = label.to(DEVICE)  # Move label to the same device as the model

                    output = model(data)
                    loss = criterion(output, label)
                    valid_loss += loss.item() * data.size(0)

                    _, pred = torch.max(output, dim=1)
                    correct_tensor = pred.eq(label.data.view_as(pred))
                    accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))
                    valid_acc += accuracy.item() * data.size(0)

            valid_loss = valid_loss / len(val_loader.dataset)
            valid_acc = valid_acc / len(val_loader.dataset)

        train_loss = train_loss / len(train_loader.dataset)
        train_acc = train_acc / len(train_loader.dataset)

        train_acc_list.append(train_acc)
        train_loss_list.append(train_loss)
        val_acc_list.append(valid_acc)
        val_loss_list.append(valid_loss)

        save_checkpoint(model, optimizer, train_loss_list, val_loss_list, train_acc_list, val_acc_list, epoch, batch_num,
                        checkpoint_location)

        if (epoch + 1) % print_every == 0:
            print(f'\nEpoch: {epoch} \tTraining Loss: {train_loss:.4f} \tValidation Loss: {valid_loss:.4f}')
            print(f'\t\tTraining Accuracy: {100 * train_acc:.2f}%\t Validation Accuracy: {100 * valid_acc:.2f}%')

            if valid_acc > valid_acc_max:
                torch.save({'state_dict': model.state_dict()}, save_location)
                stop_count = 0
                valid_acc_max = valid_acc
                best_epoch = epoch
            else:
                stop_count += 1
                if stop_count >= early_stop:
                    print(f'\nEarly Stopping Total epochs: {epoch}. Best epoch: {best_epoch} with best val acc: {100 * valid_acc_max:.2f}%')
                    model.load_state_dict(torch.load(save_location)['state_dict'])
                    model.optimizer = optimizer
                    return model

    model.optimizer = optimizer
    return model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
if False:
  zip_ref = zipfile.ZipFile('/content/drive/MyDrive/trial.zip', 'r')
  zip_ref.extractall()

# %%
# Creating the dataset
data_dir = 'trial'
event_dir = ['Cards', 'Corner', 'Event', 'Free-Kick', 'Penalty', 'Red-Cards', 'Tackle', 'To_Subtitue', 'Yellow-Cards']
non_event_dir = ['Center', 'Left', 'Right']

# %%
# The data that is in ./trial/event is class 0 and ./trial/non_event is class 1
# The data is split into 80% train and 20% test
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir, event_dir, non_event_dir, transform=None):
        self.data_dir = data_dir
        self.event_dir = event_dir
        self.non_event_dir = non_event_dir
        self.transform = transform
        self.data = []
        self.label = []
        self.event_len = 0
        self.non_event_len = 0

        for event in self.event_dir:
            event_path = os.path.join(self.data_dir, event)
            for file in os.listdir(event_path):
                self.data.append(os.path.join(event_path, file))
                self.label.append(0)
                self.event_len += 1

        for non_event in self.non_event_dir:
            non_event_path = os.path.join(self.data_dir, non_event)
            for file in os.listdir(non_event_path):
                self.data.append(os.path.join(non_event_path, file))
                self.label.append(1)
                self.non_event_len += 1

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img = Image.open(self.data[idx])
        img = img.convert('RGB')
        label = self.label[idx]
        if self.transform:
            img = self.transform(img)
        return img, label

    def get_event_len(self):
        return self.event_len

    def get_non_event_len(self):
        return self.non_event_len

    def get_data(self):
        return self.data

    def get_label(self):
        return self.label

# %%
thedata = CustomDataset(data_dir, event_dir, non_event_dir, transform=transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()]))

# %%
# Splitting the data into train and test
TRAIN_PCT = 0.8
train_size = int(TRAIN_PCT * len(thedata))
test_size = len(thedata) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(thedata, [train_size, test_size])

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True)

# %%
model = train(model, criterion, optimizer, train_loader, test_loader, save_location='nfnet_best.pth.tar',checkpoint_location='nfnet_checkpoint.pth.tar')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0	1.42% complete.
# Epoch: 0	2.72% complete.
# Epoch: 0	4.02% complete.
# Epoch: 0	5.31% complete.
# Epoch: 0	6.61% complete.
# Epoch: 0	7.90% complete.
# Epoch: 0	9.20% complete.
# Epoch: 0	10.49% complete.
# Epoch: 0	11.79% complete.
# Epoch: 0	13.08% complete.
# Epoch: 0	14.38% complete.
# Epoch: 0	15.67% complete.
# Epoch: 0	16.97% complete.
# Epoch: 0	18.26% complete.
# Epoch: 0	19.56% complete.
# Epoch: 0	20.85% complete.
# Epoch: 0	22.15% complete.
# Epoch: 0	23.45% complete.
# Epoch: 0	24.74% complete.
# Epoch: 0	26.04% complete.
# Epoch: 0	27.33% complete.
# Epoch: 0	28.63% complete.
# Epoch: 0	29.92% complete.
# Epoch: 0	31.22% complete.
# Epoch: 0	32.51% complete.
# Epoch: 0	33.81% complete.
# Epoch: 0	35.10% complete.
# Epoch: 0	36.40% complete.
# Epoch: 0	37.69% complete.
# Epoch: 0	38.99% complete.
# Epoch: 0	40.28% complete.
# Epoch: 0	41.58% complete.
# Epoch: 0	42.88% complete.
# Epoch: 0	44.17% complete.
# Epoch: 0	45.47% complete.
# Epoch: 0	46.76% complete.
# Epoch: 0	48.06% complete.
# Epoch: 0	49.35% complete.
# Epoch: 0	50.65% complete.
# Epoch: 0	51.94% complete.
# Epoch: 0	53.24% complete.
# Epoch: 0	54.53% complete.
# Epoch: 0	55.83% complete.
# Epoch: 0	57.12% complete.
# Epoch: 0	58.42% complete.
# Epoch: 0	59.72% complete.
# Epoch: 0	61.01% complete.
# Epoch: 0	62.31% complete.
# Epoch: 0	63.60% complete.
# Epoch: 0	64.90% complete.
# Epoch: 0	66.19% complete.
# Epoch: 0	67.49% complete.
# Epoch: 0	68.78% complete.
# Epoch: 0	70.08% complete.
# Epoch: 0	71.37% complete.
# Epoch: 0	72.67% complete.
# Epoch: 0	73.96% complete.
# Epoch: 0	75.26% complete.
# Epoch: 0	76.55% complete.
# Epoch: 0	77.85% complete.
# Epoch: 0	79.15% complete.
# Epoch: 0	80.44% complete.
# Epoch: 0	81.74% complete.
# Epoch: 0	83.03% complete.
# Epoch: 0	84.33% complete.
# Epoch: 0	85.62% complete.
# Epoch: 0	86.92% complete.
# Epoch: 0	88.21% complete.
# Epoch: 0	89.51% complete.
# Epoch: 0	90.80% complete.
# Epoch: 0	92.10% complete.
# Epoch: 0	93.39% complete.
# Epoch: 0	94.69% complete.
# Epoch: 0	95.98% complete.
# Epoch: 0	97.28% complete.
# Epoch: 0	98.58% complete.
# Epoch: 0	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 0 	Training Loss: 0.1890 	Validation Loss: 0.0751
# 		Training Accuracy: 94.35%	 Validation Accuracy: 97.21%
# Epoch: 1	1.42% complete.
# Epoch: 1	2.72% complete.
# Epoch: 1	4.02% complete.
# Epoch: 1	5.31% complete.
# Epoch: 1	6.61% complete.
# Epoch: 1	7.90% complete.
# Epoch: 1	9.20% complete.
# Epoch: 1	10.49% complete.
# Epoch: 1	11.79% complete.
# Epoch: 1	13.08% complete.
# Epoch: 1	14.38% complete.
# Epoch: 1	15.67% complete.
# Epoch: 1	16.97% complete.
# Epoch: 1	18.26% complete.
# Epoch: 1	19.56% complete.
# Epoch: 1	20.85% complete.
# Epoch: 1	22.15% complete.
# Epoch: 1	23.45% complete.
# Epoch: 1	24.74% complete.
# Epoch: 1	26.04% complete.
# Epoch: 1	27.33% complete.
# Epoch: 1	28.63% complete.
# Epoch: 1	29.92% complete.
# Epoch: 1	31.22% complete.
# Epoch: 1	32.51% complete.
# Epoch: 1	33.81% complete.
# Epoch: 1	35.10% complete.
# Epoch: 1	36.40% complete.
# Epoch: 1	37.69% complete.
# Epoch: 1	38.99% complete.
# Epoch: 1	40.28% complete.
# Epoch: 1	41.58% complete.
# Epoch: 1	42.88% complete.
# Epoch: 1	44.17% complete.
# Epoch: 1	45.47% complete.
# Epoch: 1	46.76% complete.
# Epoch: 1	48.06% complete.
# Epoch: 1	49.35% complete.
# Epoch: 1	50.65% complete.
# Epoch: 1	51.94% complete.
# Epoch: 1	53.24% complete.
# Epoch: 1	54.53% complete.
# Epoch: 1	55.83% complete.
# Epoch: 1	57.12% complete.
# Epoch: 1	58.42% complete.
# Epoch: 1	59.72% complete.
# Epoch: 1	61.01% complete.
# Epoch: 1	62.31% complete.
# Epoch: 1	63.60% complete.
# Epoch: 1	64.90% complete.
# Epoch: 1	66.19% complete.
# Epoch: 1	67.49% complete.
# Epoch: 1	68.78% complete.
# Epoch: 1	70.08% complete.
# Epoch: 1	71.37% complete.
# Epoch: 1	72.67% complete.
# Epoch: 1	73.96% complete.
# Epoch: 1	75.26% complete.
# Epoch: 1	76.55% complete.
# Epoch: 1	77.85% complete.
# Epoch: 1	79.15% complete.
# Epoch: 1	80.44% complete.
# Epoch: 1	81.74% complete.
# Epoch: 1	83.03% complete.
# Epoch: 1	84.33% complete.
# Epoch: 1	85.62% complete.
# Epoch: 1	86.92% complete.
# Epoch: 1	88.21% complete.
# Epoch: 1	89.51% complete.
# Epoch: 1	90.80% complete.
# Epoch: 1	92.10% complete.
# Epoch: 1	93.39% complete.
# Epoch: 1	94.69% complete.
# Epoch: 1	95.98% complete.
# Epoch: 1	97.28% complete.
# Epoch: 1	98.58% complete.
# Epoch: 1	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 1 	Training Loss: 0.0605 	Validation Loss: 0.0550
# 		Training Accuracy: 97.98%	 Validation Accuracy: 98.02%
# Epoch: 2	1.42% complete.
# Epoch: 2	2.72% complete.
# Epoch: 2	4.02% complete.
# Epoch: 2	5.31% complete.
# Epoch: 2	6.61% complete.
# Epoch: 2	7.90% complete.
# Epoch: 2	9.20% complete.
# Epoch: 2	10.49% complete.
# Epoch: 2	11.79% complete.
# Epoch: 2	13.08% complete.
# Epoch: 2	14.38% complete.
# Epoch: 2	15.67% complete.
# Epoch: 2	16.97% complete.
# Epoch: 2	18.26% complete.
# Epoch: 2	19.56% complete.
# Epoch: 2	20.85% complete.
# Epoch: 2	22.15% complete.
# Epoch: 2	23.45% complete.
# Epoch: 2	24.74% complete.
# Epoch: 2	26.04% complete.
# Epoch: 2	27.33% complete.
# Epoch: 2	28.63% complete.
# Epoch: 2	29.92% complete.
# Epoch: 2	31.22% complete.
# Epoch: 2	32.51% complete.
# Epoch: 2	33.81% complete.
# Epoch: 2	35.10% complete.
# Epoch: 2	36.40% complete.
# Epoch: 2	37.69% complete.
# Epoch: 2	38.99% complete.
# Epoch: 2	40.28% complete.
# Epoch: 2	41.58% complete.
# Epoch: 2	42.88% complete.
# Epoch: 2	44.17% complete.
# Epoch: 2	45.47% complete.
# Epoch: 2	46.76% complete.
# Epoch: 2	48.06% complete.
# Epoch: 2	49.35% complete.
# Epoch: 2	50.65% complete.
# Epoch: 2	51.94% complete.
# Epoch: 2	53.24% complete.
# Epoch: 2	54.53% complete.
# Epoch: 2	55.83% complete.
# Epoch: 2	57.12% complete.
# Epoch: 2	58.42% complete.
# Epoch: 2	59.72% complete.
# Epoch: 2	61.01% complete.
# Epoch: 2	62.31% complete.
# Epoch: 2	63.60% complete.
# Epoch: 2	64.90% complete.
# Epoch: 2	66.19% complete.
# Epoch: 2	67.49% complete.
# Epoch: 2	68.78% complete.
# Epoch: 2	70.08% complete.
# Epoch: 2	71.37% complete.
# Epoch: 2	72.67% complete.
# Epoch: 2	73.96% complete.
# Epoch: 2	75.26% complete.
# Epoch: 2	76.55% complete.
# Epoch: 2	77.85% complete.
# Epoch: 2	79.15% complete.
# Epoch: 2	80.44% complete.
# Epoch: 2	81.74% complete.
# Epoch: 2	83.03% complete.
# Epoch: 2	84.33% complete.
# Epoch: 2	85.62% complete.
# Epoch: 2	86.92% complete.
# Epoch: 2	88.21% complete.
# Epoch: 2	89.51% complete.
# Epoch: 2	90.80% complete.
# Epoch: 2	92.10% complete.
# Epoch: 2	93.39% complete.
# Epoch: 2	94.69% complete.
# Epoch: 2	95.98% complete.
# Epoch: 2	97.28% complete.
# Epoch: 2	98.58% complete.
# Epoch: 2	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 2 	Training Loss: 0.0472 	Validation Loss: 0.0470
# 		Training Accuracy: 98.50%	 Validation Accuracy: 98.27%
# Epoch: 3	1.42% complete.
# Epoch: 3	2.72% complete.
# Epoch: 3	4.02% complete.
# Epoch: 3	5.31% complete.
# Epoch: 3	6.61% complete.
# Epoch: 3	7.90% complete.
# Epoch: 3	9.20% complete.
# Epoch: 3	10.49% complete.
# Epoch: 3	11.79% complete.
# Epoch: 3	13.08% complete.
# Epoch: 3	14.38% complete.
# Epoch: 3	15.67% complete.
# Epoch: 3	16.97% complete.
# Epoch: 3	18.26% complete.
# Epoch: 3	19.56% complete.
# Epoch: 3	20.85% complete.
# Epoch: 3	22.15% complete.
# Epoch: 3	23.45% complete.
# Epoch: 3	24.74% complete.
# Epoch: 3	26.04% complete.
# Epoch: 3	27.33% complete.
# Epoch: 3	28.63% complete.
# Epoch: 3	29.92% complete.
# Epoch: 3	31.22% complete.
# Epoch: 3	32.51% complete.
# Epoch: 3	33.81% complete.
# Epoch: 3	35.10% complete.
# Epoch: 3	36.40% complete.
# Epoch: 3	37.69% complete.
# Epoch: 3	38.99% complete.
# Epoch: 3	40.28% complete.
# Epoch: 3	41.58% complete.
# Epoch: 3	42.88% complete.
# Epoch: 3	44.17% complete.
# Epoch: 3	45.47% complete.
# Epoch: 3	46.76% complete.
# Epoch: 3	48.06% complete.
# Epoch: 3	49.35% complete.
# Epoch: 3	50.65% complete.
# Epoch: 3	51.94% complete.
# Epoch: 3	53.24% complete.
# Epoch: 3	54.53% complete.
# Epoch: 3	55.83% complete.
# Epoch: 3	57.12% complete.
# Epoch: 3	58.42% complete.
# Epoch: 3	59.72% complete.
# Epoch: 3	61.01% complete.
# Epoch: 3	62.31% complete.
# Epoch: 3	63.60% complete.
# Epoch: 3	64.90% complete.
# Epoch: 3	66.19% complete.
# Epoch: 3	67.49% complete.
# Epoch: 3	68.78% complete.
# Epoch: 3	70.08% complete.
# Epoch: 3	71.37% complete.
# Epoch: 3	72.67% complete.
# Epoch: 3	73.96% complete.
# Epoch: 3	75.26% complete.
# Epoch: 3	76.55% complete.
# Epoch: 3	77.85% complete.
# Epoch: 3	79.15% complete.
# Epoch: 3	80.44% complete.
# Epoch: 3	81.74% complete.
# Epoch: 3	83.03% complete.
# Epoch: 3	84.33% complete.
# Epoch: 3	85.62% complete.
# Epoch: 3	86.92% complete.
# Epoch: 3	88.21% complete.
# Epoch: 3	89.51% complete.
# Epoch: 3	90.80% complete.
# Epoch: 3	92.10% complete.
# Epoch: 3	93.39% complete.
# Epoch: 3	94.69% complete.
# Epoch: 3	95.98% complete.
# Epoch: 3	97.28% complete.
# Epoch: 3	98.58% complete.
# Epoch: 3	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 3 	Training Loss: 0.0395 	Validation Loss: 0.0412
# 		Training Accuracy: 98.73%	 Validation Accuracy: 98.57%
# Epoch: 4	1.42% complete.
# Epoch: 4	2.72% complete.
# Epoch: 4	4.02% complete.
# Epoch: 4	5.31% complete.
# Epoch: 4	6.61% complete.
# Epoch: 4	7.90% complete.
# Epoch: 4	9.20% complete.
# Epoch: 4	10.49% complete.
# Epoch: 4	11.79% complete.
# Epoch: 4	13.08% complete.
# Epoch: 4	14.38% complete.
# Epoch: 4	15.67% complete.
# Epoch: 4	16.97% complete.
# Epoch: 4	18.26% complete.
# Epoch: 4	19.56% complete.
# Epoch: 4	20.85% complete.
# Epoch: 4	22.15% complete.
# Epoch: 4	23.45% complete.
# Epoch: 4	24.74% complete.
# Epoch: 4	26.04% complete.
# Epoch: 4	27.33% complete.
# Epoch: 4	28.63% complete.
# Epoch: 4	29.92% complete.
# Epoch: 4	31.22% complete.
# Epoch: 4	32.51% complete.
# Epoch: 4	33.81% complete.
# Epoch: 4	35.10% complete.
# Epoch: 4	36.40% complete.
# Epoch: 4	37.69% complete.
# Epoch: 4	38.99% complete.
# Epoch: 4	40.28% complete.
# Epoch: 4	41.58% complete.
# Epoch: 4	42.88% complete.
# Epoch: 4	44.17% complete.
# Epoch: 4	45.47% complete.
# Epoch: 4	46.76% complete.
# Epoch: 4	48.06% complete.
# Epoch: 4	49.35% complete.
# Epoch: 4	50.65% complete.
# Epoch: 4	51.94% complete.
# Epoch: 4	53.24% complete.
# Epoch: 4	54.53% complete.
# Epoch: 4	55.83% complete.
# Epoch: 4	57.12% complete.
# Epoch: 4	58.42% complete.
# Epoch: 4	59.72% complete.
# Epoch: 4	61.01% complete.
# Epoch: 4	62.31% complete.
# Epoch: 4	63.60% complete.
# Epoch: 4	64.90% complete.
# Epoch: 4	66.19% complete.
# Epoch: 4	67.49% complete.
# Epoch: 4	68.78% complete.
# Epoch: 4	70.08% complete.
# Epoch: 4	71.37% complete.
# Epoch: 4	72.67% complete.
# Epoch: 4	73.96% complete.
# Epoch: 4	75.26% complete.
# Epoch: 4	76.55% complete.
# Epoch: 4	77.85% complete.
# Epoch: 4	79.15% complete.
# Epoch: 4	80.44% complete.
# Epoch: 4	81.74% complete.
# Epoch: 4	83.03% complete.
# Epoch: 4	84.33% complete.
# Epoch: 4	85.62% complete.
# Epoch: 4	86.92% complete.
# Epoch: 4	88.21% complete.
# Epoch: 4	89.51% complete.
# Epoch: 4	90.80% complete.
# Epoch: 4	92.10% complete.
# Epoch: 4	93.39% complete.
# Epoch: 4	94.69% complete.
# Epoch: 4	95.98% complete.
# Epoch: 4	97.28% complete.
# Epoch: 4	98.58% complete.
# Epoch: 4	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 4 	Training Loss: 0.0343 	Validation Loss: 0.0366
# 		Training Accuracy: 98.90%	 Validation Accuracy: 98.67%
# Epoch: 5	1.42% complete.
# Epoch: 5	2.72% complete.
# Epoch: 5	4.02% complete.
# Epoch: 5	5.31% complete.
# Epoch: 5	6.61% complete.
# Epoch: 5	7.90% complete.
# Epoch: 5	9.20% complete.
# Epoch: 5	10.49% complete.
# Epoch: 5	11.79% complete.
# Epoch: 5	13.08% complete.
# Epoch: 5	14.38% complete.
# Epoch: 5	15.67% complete.
# Epoch: 5	16.97% complete.
# Epoch: 5	18.26% complete.
# Epoch: 5	19.56% complete.
# Epoch: 5	20.85% complete.
# Epoch: 5	22.15% complete.
# Epoch: 5	23.45% complete.
# Epoch: 5	24.74% complete.
# Epoch: 5	26.04% complete.
# Epoch: 5	27.33% complete.
# Epoch: 5	28.63% complete.
# Epoch: 5	29.92% complete.
# Epoch: 5	31.22% complete.
# Epoch: 5	32.51% complete.
# Epoch: 5	33.81% complete.
# Epoch: 5	35.10% complete.
# Epoch: 5	36.40% complete.
# Epoch: 5	37.69% complete.
# Epoch: 5	38.99% complete.
# Epoch: 5	40.28% complete.
# Epoch: 5	41.58% complete.
# Epoch: 5	42.88% complete.
# Epoch: 5	44.17% complete.
# Epoch: 5	45.47% complete.
# Epoch: 5	46.76% complete.
# Epoch: 5	48.06% complete.
# Epoch: 5	49.35% complete.
# Epoch: 5	50.65% complete.
# Epoch: 5	51.94% complete.
# Epoch: 5	53.24% complete.
# Epoch: 5	54.53% complete.
# Epoch: 5	55.83% complete.
# Epoch: 5	57.12% complete.
# Epoch: 5	58.42% complete.
# Epoch: 5	59.72% complete.
# Epoch: 5	61.01% complete.
# Epoch: 5	62.31% complete.
# Epoch: 5	63.60% complete.
# Epoch: 5	64.90% complete.
# Epoch: 5	66.19% complete.
# Epoch: 5	67.49% complete.
# Epoch: 5	68.78% complete.
# Epoch: 5	70.08% complete.
# Epoch: 5	71.37% complete.
# Epoch: 5	72.67% complete.
# Epoch: 5	73.96% complete.
# Epoch: 5	75.26% complete.
# Epoch: 5	76.55% complete.
# Epoch: 5	77.85% complete.
# Epoch: 5	79.15% complete.
# Epoch: 5	80.44% complete.
# Epoch: 5	81.74% complete.
# Epoch: 5	83.03% complete.
# Epoch: 5	84.33% complete.
# Epoch: 5	85.62% complete.
# Epoch: 5	86.92% complete.
# Epoch: 5	88.21% complete.
# Epoch: 5	89.51% complete.
# Epoch: 5	90.80% complete.
# Epoch: 5	92.10% complete.
# Epoch: 5	93.39% complete.
# Epoch: 5	94.69% complete.
# Epoch: 5	95.98% complete.
# Epoch: 5	97.28% complete.
# Epoch: 5	98.58% complete.
# Epoch: 5	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 5 	Training Loss: 0.0305 	Validation Loss: 0.0344
# 		Training Accuracy: 99.01%	 Validation Accuracy: 98.73%
# Epoch: 6	1.42% complete.
# Epoch: 6	2.72% complete.
# Epoch: 6	4.02% complete.
# Epoch: 6	5.31% complete.
# Epoch: 6	6.61% complete.
# Epoch: 6	7.90% complete.
# Epoch: 6	9.20% complete.
# Epoch: 6	10.49% complete.
# Epoch: 6	11.79% complete.
# Epoch: 6	13.08% complete.
# Epoch: 6	14.38% complete.
# Epoch: 6	15.67% complete.
# Epoch: 6	16.97% complete.
# Epoch: 6	18.26% complete.
# Epoch: 6	19.56% complete.
# Epoch: 6	20.85% complete.
# Epoch: 6	22.15% complete.
# Epoch: 6	23.45% complete.
# Epoch: 6	24.74% complete.
# Epoch: 6	26.04% complete.
# Epoch: 6	27.33% complete.
# Epoch: 6	28.63% complete.
# Epoch: 6	29.92% complete.
# Epoch: 6	31.22% complete.
# Epoch: 6	32.51% complete.
# Epoch: 6	33.81% complete.
# Epoch: 6	35.10% complete.
# Epoch: 6	36.40% complete.
# Epoch: 6	37.69% complete.
# Epoch: 6	38.99% complete.
# Epoch: 6	40.28% complete.
# Epoch: 6	41.58% complete.
# Epoch: 6	42.88% complete.
# Epoch: 6	44.17% complete.
# Epoch: 6	45.47% complete.
# Epoch: 6	46.76% complete.
# Epoch: 6	48.06% complete.
# Epoch: 6	49.35% complete.
# Epoch: 6	50.65% complete.
# Epoch: 6	51.94% complete.
# Epoch: 6	53.24% complete.
# Epoch: 6	54.53% complete.
# Epoch: 6	55.83% complete.
# Epoch: 6	57.12% complete.
# Epoch: 6	58.42% complete.
# Epoch: 6	59.72% complete.
# Epoch: 6	61.01% complete.
# Epoch: 6	62.31% complete.
# Epoch: 6	63.60% complete.
# Epoch: 6	64.90% complete.
# Epoch: 6	66.19% complete.
# Epoch: 6	67.49% complete.
# Epoch: 6	68.78% complete.
# Epoch: 6	70.08% complete.
# Epoch: 6	71.37% complete.
# Epoch: 6	72.67% complete.
# Epoch: 6	73.96% complete.
# Epoch: 6	75.26% complete.
# Epoch: 6	76.55% complete.
# Epoch: 6	77.85% complete.
# Epoch: 6	79.15% complete.
# Epoch: 6	80.44% complete.
# Epoch: 6	81.74% complete.
# Epoch: 6	83.03% complete.
# Epoch: 6	84.33% complete.
# Epoch: 6	85.62% complete.
# Epoch: 6	86.92% complete.
# Epoch: 6	88.21% complete.
# Epoch: 6	89.51% complete.
# Epoch: 6	90.80% complete.
# Epoch: 6	92.10% complete.
# Epoch: 6	93.39% complete.
# Epoch: 6	94.69% complete.
# Epoch: 6	95.98% complete.
# Epoch: 6	97.28% complete.
# Epoch: 6	98.58% complete.
# Epoch: 6	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 6 	Training Loss: 0.0274 	Validation Loss: 0.0319
# 		Training Accuracy: 99.14%	 Validation Accuracy: 98.82%
# Epoch: 7	1.42% complete.
# Epoch: 7	2.72% complete.
# Epoch: 7	4.02% complete.
# Epoch: 7	5.31% complete.
# Epoch: 7	6.61% complete.
# Epoch: 7	7.90% complete.
# Epoch: 7	9.20% complete.
# Epoch: 7	10.49% complete.
# Epoch: 7	11.79% complete.
# Epoch: 7	13.08% complete.
# Epoch: 7	14.38% complete.
# Epoch: 7	15.67% complete.
# Epoch: 7	16.97% complete.
# Epoch: 7	18.26% complete.
# Epoch: 7	19.56% complete.
# Epoch: 7	20.85% complete.
# Epoch: 7	22.15% complete.
# Epoch: 7	23.45% complete.
# Epoch: 7	24.74% complete.
# Epoch: 7	26.04% complete.
# Epoch: 7	27.33% complete.
# Epoch: 7	28.63% complete.
# Epoch: 7	29.92% complete.
# Epoch: 7	31.22% complete.
# Epoch: 7	32.51% complete.
# Epoch: 7	33.81% complete.
# Epoch: 7	35.10% complete.
# Epoch: 7	36.40% complete.
# Epoch: 7	37.69% complete.
# Epoch: 7	38.99% complete.
# Epoch: 7	40.28% complete.
# Epoch: 7	41.58% complete.
# Epoch: 7	42.88% complete.
# Epoch: 7	44.17% complete.
# Epoch: 7	45.47% complete.
# Epoch: 7	46.76% complete.
# Epoch: 7	48.06% complete.
# Epoch: 7	49.35% complete.
# Epoch: 7	50.65% complete.
# Epoch: 7	51.94% complete.
# Epoch: 7	53.24% complete.
# Epoch: 7	54.53% complete.
# Epoch: 7	55.83% complete.
# Epoch: 7	57.12% complete.
# Epoch: 7	58.42% complete.
# Epoch: 7	59.72% complete.
# Epoch: 7	61.01% complete.
# Epoch: 7	62.31% complete.
# Epoch: 7	63.60% complete.
# Epoch: 7	64.90% complete.
# Epoch: 7	66.19% complete.
# Epoch: 7	67.49% complete.
# Epoch: 7	68.78% complete.
# Epoch: 7	70.08% complete.
# Epoch: 7	71.37% complete.
# Epoch: 7	72.67% complete.
# Epoch: 7	73.96% complete.
# Epoch: 7	75.26% complete.
# Epoch: 7	76.55% complete.
# Epoch: 7	77.85% complete.
# Epoch: 7	79.15% complete.
# Epoch: 7	80.44% complete.
# Epoch: 7	81.74% complete.
# Epoch: 7	83.03% complete.
# Epoch: 7	84.33% complete.
# Epoch: 7	85.62% complete.
# Epoch: 7	86.92% complete.
# Epoch: 7	88.21% complete.
# Epoch: 7	89.51% complete.
# Epoch: 7	90.80% complete.
# Epoch: 7	92.10% complete.
# Epoch: 7	93.39% complete.
# Epoch: 7	94.69% complete.
# Epoch: 7	95.98% complete.
# Epoch: 7	97.28% complete.
# Epoch: 7	98.58% complete.
# Epoch: 7	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 7 	Training Loss: 0.0255 	Validation Loss: 0.0330
# 		Training Accuracy: 99.18%	 Validation Accuracy: 98.95%
# Epoch: 8	1.42% complete.
# Epoch: 8	2.72% complete.
# Epoch: 8	4.02% complete.
# Epoch: 8	5.31% complete.
# Epoch: 8	6.61% complete.
# Epoch: 8	7.90% complete.
# Epoch: 8	9.20% complete.
# Epoch: 8	10.49% complete.
# Epoch: 8	11.79% complete.
# Epoch: 8	13.08% complete.
# Epoch: 8	14.38% complete.
# Epoch: 8	15.67% complete.
# Epoch: 8	16.97% complete.
# Epoch: 8	18.26% complete.
# Epoch: 8	19.56% complete.
# Epoch: 8	20.85% complete.
# Epoch: 8	22.15% complete.
# Epoch: 8	23.45% complete.
# Epoch: 8	24.74% complete.
# Epoch: 8	26.04% complete.
# Epoch: 8	27.33% complete.
# Epoch: 8	28.63% complete.
# Epoch: 8	29.92% complete.
# Epoch: 8	31.22% complete.
# Epoch: 8	32.51% complete.
# Epoch: 8	33.81% complete.
# Epoch: 8	35.10% complete.
# Epoch: 8	36.40% complete.
# Epoch: 8	37.69% complete.
# Epoch: 8	38.99% complete.
# Epoch: 8	40.28% complete.
# Epoch: 8	41.58% complete.
# Epoch: 8	42.88% complete.
# Epoch: 8	44.17% complete.
# Epoch: 8	45.47% complete.
# Epoch: 8	46.76% complete.
# Epoch: 8	48.06% complete.
# Epoch: 8	49.35% complete.
# Epoch: 8	50.65% complete.
# Epoch: 8	51.94% complete.
# Epoch: 8	53.24% complete.
# Epoch: 8	54.53% complete.
# Epoch: 8	55.83% complete.
# Epoch: 8	57.12% complete.
# Epoch: 8	58.42% complete.
# Epoch: 8	59.72% complete.
# Epoch: 8	61.01% complete.
# Epoch: 8	62.31% complete.
# Epoch: 8	63.60% complete.
# Epoch: 8	64.90% complete.
# Epoch: 8	66.19% complete.
# Epoch: 8	67.49% complete.
# Epoch: 8	68.78% complete.
# Epoch: 8	70.08% complete.
# Epoch: 8	71.37% complete.
# Epoch: 8	72.67% complete.
# Epoch: 8	73.96% complete.
# Epoch: 8	75.26% complete.
# Epoch: 8	76.55% complete.
# Epoch: 8	77.85% complete.
# Epoch: 8	79.15% complete.
# Epoch: 8	80.44% complete.
# Epoch: 8	81.74% complete.
# Epoch: 8	83.03% complete.
# Epoch: 8	84.33% complete.
# Epoch: 8	85.62% complete.
# Epoch: 8	86.92% complete.
# Epoch: 8	88.21% complete.
# Epoch: 8	89.51% complete.
# Epoch: 8	90.80% complete.
# Epoch: 8	92.10% complete.
# Epoch: 8	93.39% complete.
# Epoch: 8	94.69% complete.
# Epoch: 8	95.98% complete.
# Epoch: 8	97.28% complete.
# Epoch: 8	98.58% complete.
# Epoch: 8	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 8 	Training Loss: 0.0232 	Validation Loss: 0.0292
# 		Training Accuracy: 99.26%	 Validation Accuracy: 98.94%
# Epoch: 9	1.42% complete.
# Epoch: 9	2.72% complete.
# Epoch: 9	4.02% complete.
# Epoch: 9	5.31% complete.
# Epoch: 9	6.61% complete.
# Epoch: 9	7.90% complete.
# Epoch: 9	9.20% complete.
# Epoch: 9	10.49% complete.
# Epoch: 9	11.79% complete.
# Epoch: 9	13.08% complete.
# Epoch: 9	14.38% complete.
# Epoch: 9	15.67% complete.
# Epoch: 9	16.97% complete.
# Epoch: 9	18.26% complete.
# Epoch: 9	19.56% complete.
# Epoch: 9	20.85% complete.
# Epoch: 9	22.15% complete.
# Epoch: 9	23.45% complete.
# Epoch: 9	24.74% complete.
# Epoch: 9	26.04% complete.
# Epoch: 9	27.33% complete.
# Epoch: 9	28.63% complete.
# Epoch: 9	29.92% complete.
# Epoch: 9	31.22% complete.
# Epoch: 9	32.51% complete.
# Epoch: 9	33.81% complete.
# Epoch: 9	35.10% complete.
# Epoch: 9	36.40% complete.
# Epoch: 9	37.69% complete.
# Epoch: 9	38.99% complete.
# Epoch: 9	40.28% complete.
# Epoch: 9	41.58% complete.
# Epoch: 9	42.88% complete.
# Epoch: 9	44.17% complete.
# Epoch: 9	45.47% complete.
# Epoch: 9	46.76% complete.
# Epoch: 9	48.06% complete.
# Epoch: 9	49.35% complete.
# Epoch: 9	50.65% complete.
# Epoch: 9	51.94% complete.
# Epoch: 9	53.24% complete.
# Epoch: 9	54.53% complete.
# Epoch: 9	55.83% complete.
# Epoch: 9	57.12% complete.
# Epoch: 9	58.42% complete.
# Epoch: 9	59.72% complete.
# Epoch: 9	61.01% complete.
# Epoch: 9	62.31% complete.
# Epoch: 9	63.60% complete.
# Epoch: 9	64.90% complete.
# Epoch: 9	66.19% complete.
# Epoch: 9	67.49% complete.
# Epoch: 9	68.78% complete.
# Epoch: 9	70.08% complete.
# Epoch: 9	71.37% complete.
# Epoch: 9	72.67% complete.
# Epoch: 9	73.96% complete.
# Epoch: 9	75.26% complete.
# Epoch: 9	76.55% complete.
# Epoch: 9	77.85% complete.
# Epoch: 9	79.15% complete.
# Epoch: 9	80.44% complete.
# Epoch: 9	81.74% complete.
# Epoch: 9	83.03% complete.
# Epoch: 9	84.33% complete.
# Epoch: 9	85.62% complete.
# Epoch: 9	86.92% complete.
# Epoch: 9	88.21% complete.
# Epoch: 9	89.51% complete.
# Epoch: 9	90.80% complete.
# Epoch: 9	92.10% complete.
# Epoch: 9	93.39% complete.
# Epoch: 9	94.69% complete.
# Epoch: 9	95.98% complete.
# Epoch: 9	97.28% complete.
# Epoch: 9	98.58% complete.
# Epoch: 9	99.87% complete.
# Model saved to nfnet_checkpoint.pth.tar.
#
# Epoch: 9 	Training Loss: 0.0214 	Validation Loss: 0.0299
# 		Training Accuracy: 99.32%	 Validation Accuracy: 99.05%
